# %% [markdown]
# ## Potential New Customer Data

# %% [markdown]
# KPMG has asked us to profile some potential customers for a targeted advert. The aim is to conduct sales and marketing campaigne with the limited available resources in order to increase sales and revenue. The data set was provided by KPMG and contains 1000 records and 23 featues. It is unclean and comprises of 1000 records and 23 features. It needs to go through some preporcessing steps, so that it can be fed into the machine learning model for prediction.

# %%
# importing the rquired libraries for he analysis
import numpy as np
import pandas as pd
import datetime

# %%
#load the data and view a samples of the data
new_cust = pd.read_excel('C:/Users/Chuks/datasets/kpmg_new_customer.xlsx')
new_cust.sample(5)
# Out:
#     first_name   last_name  gender  past_3_years_bike_related_purchases  \
# 290   Vittoria     Whitney  Female                                   95
# 381     Almira     Mangion  Female                                    4
# 954    Lyndell     Jereatt  Female                                   14
# 38       Garik    Whitwell    Male                                   44
# 240      Farra  Matyushkin  Female                                   18
#
#            DOB                       job_title job_industry_category  \
# 290 1981-06-03            Research Assistant I                   NaN
# 381 1996-01-24           VP Product Management    Financial Services
# 954 1994-11-28  Payment Adjustment Coordinator                   NaN
# 38  1955-06-13                             NaN              Property
# 240 1974-01-24              VP Quality Control         Manufacturing
#
#         wealth_segment deceased_indicator owns_car  ...  state    country  \
# 290     High Net Worth                  N       No  ...    NSW  Australia
# 381  Affluent Customer                  N      Yes  ...    NSW  Australia
# 954     High Net Worth                  N       No  ...    NSW  Australia
# 38       Mass Customer                  N      Yes  ...    VIC  Australia
# 240     High Net Worth                  N      Yes  ...    VIC  Australia
#
#      property_valuation Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 290                  11        1.07      1.0700     1.337500     1.337500
# 381                  12        0.52      0.6500     0.812500     0.812500
# 954                  12        0.50      0.5000     0.625000     0.625000
# 38                    2        0.88      1.1000     1.100000     0.935000
# 240                   9        0.79      0.9875     1.234375     1.234375
#
#      Unnamed: 20  Rank     Value
# 290          291   291  1.035937
# 381          382   382  0.950000
# 954          954   954  0.450000
# 38            38    38  1.437500
# 240          241   241  1.087500
#
# [5 rows x 23 columns]

# %%
new_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
#  11  address                              1000 non-null   object
#  12  postcode                             1000 non-null   int64
#  13  state                                1000 non-null   object
#  14  country                              1000 non-null   object
#  15  property_valuation                   1000 non-null   int64
#  16  Unnamed: 16                          1000 non-null   float64
#  17  Unnamed: 17                          1000 non-null   float64
#  18  Unnamed: 18                          1000 non-null   float64
#  19  Unnamed: 19                          1000 non-null   float64
#  20  Unnamed: 20                          1000 non-null   int64
#  21  Rank                                 1000 non-null   int64
#  22  Value                                1000 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(11)
# memory usage: 179.8+ KB

# %% [markdown]
# There a couple of missing values in last_name, DOB, job_title and job_industry_category. Some features have irrelevant data that doesn't seem to making any meaning. The 'country' and 'deceased_indicator' columns have single value in the column and can as wll be dropped. The columns that need to be removed are: 'first_name', 'last_name', 'job_title', 'DOB', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Rank', 'Unnamed: 19', 'Unnamed: 20', 'country', 'address', 'deceased_indicator', 'Value', 'postcode'.

# %%
# deceased_indicator and country are single value are irrelevant
print(new_cust['deceased_indicator'].unique())
print(new_cust['country'].unique())
# Out:
# ['N']
# ['Australia']

# %%
# converting the date of birth to age 
now = pd.Timestamp('now')
new_cust['age'] = (now.year - new_cust['DOB'].dt.year) - ((now.month - new_cust['DOB'].dt.month) < 0)

# %%
#dropping some irrelevant columns
new_cust = new_cust.drop(['first_name', 'last_name', 'job_title', 'DOB', 'Unnamed: 16', 'Unnamed: 17', 
                          'Unnamed: 18', 'Rank', 'Unnamed: 19', 'Unnamed: 20', 'country', 'address', 
                          'deceased_indicator', 'Value', 'postcode'], axis=1)

# %%
new_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   gender                               1000 non-null   object
#  1   past_3_years_bike_related_purchases  1000 non-null   int64
#  2   job_industry_category                835 non-null    object
#  3   wealth_segment                       1000 non-null   object
#  4   owns_car                             1000 non-null   object
#  5   tenure                               1000 non-null   int64
#  6   state                                1000 non-null   object
#  7   property_valuation                   1000 non-null   int64
#  8   age                                  983 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ KB

# %%
# segmenting people into groups of young adult, adult and senior based on their respective age
cut_points = [17,35,60,90]
label_names = ["young adult","adult","senior"]
new_cust["age_categories"] = pd.cut(new_cust["age"],cut_points,labels=label_names)

# %%
new_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   gender                               1000 non-null   object
#  1   past_3_years_bike_related_purchases  1000 non-null   int64
#  2   job_industry_category                835 non-null    object
#  3   wealth_segment                       1000 non-null   object
#  4   owns_car                             1000 non-null   object
#  5   tenure                               1000 non-null   int64
#  6   state                                1000 non-null   object
#  7   property_valuation                   1000 non-null   int64
#  8   age                                  983 non-null    float64
#  9   age_categories                       983 non-null    category
# dtypes: category(1), float64(1), int64(3), object(5)
# memory usage: 71.5+ KB

# %%
new_cust['age'].dtype
# Out:
# dtype('float64')

# %%
#converting agefrom float to int
new_cust['age'] = np.array(new_cust['age']).astype(int)

# %%
#converting age_category from category to object
new_cust['age_categories'] = new_cust['age_categories'].astype(str)

# %%
new_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   gender                               1000 non-null   object
#  1   past_3_years_bike_related_purchases  1000 non-null   int64
#  2   job_industry_category                835 non-null    object
#  3   wealth_segment                       1000 non-null   object
#  4   owns_car                             1000 non-null   object
#  5   tenure                               1000 non-null   int64
#  6   state                                1000 non-null   object
#  7   property_valuation                   1000 non-null   int64
#  8   age                                  1000 non-null   int32
#  9   age_categories                       1000 non-null   object
# dtypes: int32(1), int64(3), object(6)
# memory usage: 74.3+ KB

# %%
# erroneous age data
erroneous_age = new_cust[new_cust['age'] == -2147483648]
erroneous_age
# Out:
#     gender  past_3_years_bike_related_purchases job_industry_category  \
# 59       U                                    5                    IT
# 226      U                                   35                    IT
# 324      U                                   69                    IT
# 358      U                                   65         Entertainment
# 360      U                                   71                    IT
# 374      U                                   66                    IT
# 434      U                                   52                    IT
# 439      U                                   93                    IT
# 574      U                                   69                    IT
# 598      U                                   15                    IT
# 664      U                                   43                    IT
# 751      U                                   20                    IT
# 775      U                                   62    Financial Services
# 835      U                                   88                    IT
# 883      U                                   24                    IT
# 904      U                                    0                    IT
# 984      U                                   82                    IT
#
#         wealth_segment owns_car  tenure state  property_valuation         age  \
# 59       Mass Customer       No       4   VIC                   5 -2147483648
# 226  Affluent Customer      Yes      11   NSW                   9 -2147483648
# 324      Mass Customer      Yes       3   VIC                   3 -2147483648
# 358  Affluent Customer       No       5   QLD                   8 -2147483648
# 360      Mass Customer      Yes      11   VIC                   7 -2147483648
# 374      Mass Customer       No      15   QLD                   6 -2147483648
# 434      Mass Customer       No       7   VIC                   5 -2147483648
# 439      Mass Customer      Yes      14   VIC                   6 -2147483648
# 574      Mass Customer       No      12   NSW                   7 -2147483648
# 598  Affluent Customer       No       5   NSW                  11 -2147483648
# 664     High Net Worth      Yes       0   VIC                   4 -2147483648
# 751     High Net Worth      Yes      14   VIC                   7 -2147483648
# 775  Affluent Customer       No       5   VIC                   1 -2147483648
# 835      Mass Customer       No      13   NSW                  11 -2147483648
# 883  Affluent Customer       No       2   NSW                  10 -2147483648
# 904      Mass Customer       No       2   NSW                   6 -2147483648
# 984  Affluent Customer      Yes       0   NSW                  10 -2147483648
#
#     age_categories
# 59             nan
# 226            nan
# 324            nan
# 358            nan
# 360            nan
# 374            nan
# 434            nan
# 439            nan
# 574            nan
# 598            nan
# 664            nan
# 751            nan
# 775            nan
# 835            nan
# 883            nan
# 904            nan
# 984            nan

# %%
# erroneous gender data
erroneous_gender = new_cust[new_cust['gender'] == 'U']
erroneous_gender
# Out:
#     gender  past_3_years_bike_related_purchases job_industry_category  \
# 59       U                                    5                    IT
# 226      U                                   35                    IT
# 324      U                                   69                    IT
# 358      U                                   65         Entertainment
# 360      U                                   71                    IT
# 374      U                                   66                    IT
# 434      U                                   52                    IT
# 439      U                                   93                    IT
# 574      U                                   69                    IT
# 598      U                                   15                    IT
# 664      U                                   43                    IT
# 751      U                                   20                    IT
# 775      U                                   62    Financial Services
# 835      U                                   88                    IT
# 883      U                                   24                    IT
# 904      U                                    0                    IT
# 984      U                                   82                    IT
#
#         wealth_segment owns_car  tenure state  property_valuation         age  \
# 59       Mass Customer       No       4   VIC                   5 -2147483648
# 226  Affluent Customer      Yes      11   NSW                   9 -2147483648
# 324      Mass Customer      Yes       3   VIC                   3 -2147483648
# 358  Affluent Customer       No       5   QLD                   8 -2147483648
# 360      Mass Customer      Yes      11   VIC                   7 -2147483648
# 374      Mass Customer       No      15   QLD                   6 -2147483648
# 434      Mass Customer       No       7   VIC                   5 -2147483648
# 439      Mass Customer      Yes      14   VIC                   6 -2147483648
# 574      Mass Customer       No      12   NSW                   7 -2147483648
# 598  Affluent Customer       No       5   NSW                  11 -2147483648
# 664     High Net Worth      Yes       0   VIC                   4 -2147483648
# 751     High Net Worth      Yes      14   VIC                   7 -2147483648
# 775  Affluent Customer       No       5   VIC                   1 -2147483648
# 835      Mass Customer       No      13   NSW                  11 -2147483648
# 883  Affluent Customer       No       2   NSW                  10 -2147483648
# 904      Mass Customer       No       2   NSW                   6 -2147483648
# 984  Affluent Customer      Yes       0   NSW                  10 -2147483648
#
#     age_categories
# 59             nan
# 226            nan
# 324            nan
# 358            nan
# 360            nan
# 374            nan
# 434            nan
# 439            nan
# 574            nan
# 598            nan
# 664            nan
# 751            nan
# 775            nan
# 835            nan
# 883            nan
# 904            nan
# 984            nan

# %%
#asserting the lenght of the erraneous data
print(len(erroneous_gender))
print(len(erroneous_age))
# Out:
# 17
# 17

# %%
erroneous_gender == erroneous_age
# Out:
#      gender  past_3_years_bike_related_purchases  job_industry_category  \
# 59     True                                 True                   True
# 226    True                                 True                   True
# 324    True                                 True                   True
# 358    True                                 True                   True
# 360    True                                 True                   True
# 374    True                                 True                   True
# 434    True                                 True                   True
# 439    True                                 True                   True
# 574    True                                 True                   True
# 598    True                                 True                   True
# 664    True                                 True                   True
# 751    True                                 True                   True
# 775    True                                 True                   True
# 835    True                                 True                   True
# 883    True                                 True                   True
# 904    True                                 True                   True
# 984    True                                 True                   True
#
#      wealth_segment  owns_car  tenure  state  property_valuation   age  \
# 59             True      True    True   True                True  True
# 226            True      True    True   True                True  True
# 324            True      True    True   True                True  True
# 358            True      True    True   True                True  True
# 360            True      True    True   True                True  True
# 374            True      True    True   True                True  True
# 434            True      True    True   True                True  True
# 439            True      True    True   True                True  True
# 574            True      True    True   True                True  True
# 598            True      True    True   True                True  True
# 664            True      True    True   True                True  True
# 751            True      True    True   True                True  True
# 775            True      True    True   True                True  True
# 835            True      True    True   True                True  True
# 883            True      True    True   True                True  True
# 904            True      True    True   True                True  True
# 984            True      True    True   True                True  True
#
#      age_categories
# 59             True
# 226            True
# 324            True
# 358            True
# 360            True
# 374            True
# 434            True
# 439            True
# 574            True
# 598            True
# 664            True
# 751            True
# 775            True
# 835            True
# 883            True
# 904            True
# 984            True

# %%
#dropping the errorneous data 
new_cust = new_cust[new_cust['age'] != -2147483648]

# %%
new_cust.isnull().sum()
# Out:
# gender                                   0
# past_3_years_bike_related_purchases      0
# job_industry_category                  165
# wealth_segment                           0
# owns_car                                 0
# tenure                                   0
# state                                    0
# property_valuation                       0
# age                                      0
# age_categories                           0
# dtype: int64

# %%
new_cust = new_cust.dropna()
new_cust.isnull().sum()
# Out:
# gender                                 0
# past_3_years_bike_related_purchases    0
# job_industry_category                  0
# wealth_segment                         0
# owns_car                               0
# tenure                                 0
# state                                  0
# property_valuation                     0
# age                                    0
# age_categories                         0
# dtype: int64

# %%
new_cust
# Out:
#      gender  past_3_years_bike_related_purchases job_industry_category  \
# 0      Male                                   86         Manufacturing
# 1      Male                                   69              Property
# 2    Female                                   10    Financial Services
# 3    Female                                   64         Manufacturing
# 4    Female                                   34    Financial Services
# ..      ...                                  ...                   ...
# 995    Male                                   60    Financial Services
# 996    Male                                   22                Health
# 997  Female                                   17    Financial Services
# 998    Male                                   30    Financial Services
# 999    Male                                   56              Property
#
#         wealth_segment owns_car  tenure state  property_valuation  age  \
# 0        Mass Customer      Yes      14   QLD                   6   62
# 1        Mass Customer       No      16   NSW                  11   50
# 2    Affluent Customer       No      10   VIC                   5   45
# 3    Affluent Customer      Yes       5   QLD                   1   41
# 4    Affluent Customer       No      19   NSW                   9   54
# ..                 ...      ...     ...   ...                 ...  ...
# 995  Affluent Customer       No       9   NSW                   7   60
# 996      Mass Customer       No       6   NSW                  10   18
# 997  Affluent Customer      Yes      15   QLD                   2   65
# 998      Mass Customer      Yes      19   QLD                   2   67
# 999      Mass Customer      Yes      14   NSW                   9   64
#
#     age_categories
# 0           senior
# 1            adult
# 2            adult
# 3            adult
# 4            adult
# ..             ...
# 995          adult
# 996    young adult
# 997         senior
# 998         senior
# 999         senior
#
# [818 rows x 10 columns]

# %%
#converting categorical data to numeric data
new_cust = pd.get_dummies(new_cust)

# %%
#saving the file to excel
new_cust.to_excel('new_cust1.xlsx')
